# %%
라이브러리 임포트

# %%
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat

from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage

from scipy.ndimage import affine_transform, zoom
from scipy import misc

import matplotlib.image as mpimg
import matplotlib.pylab as plt

# %% [markdown]
# # scikit-image의 astronaut dataset 사용

# %%
im = data.astronaut()
imshow(im)
show()

# %% [markdown]
# ## scipy.misc 모둘의 얼굴 데이터셋 사용

# %%
im = misc.face()                		# 라쿤 얼굴 영상 읽기 
misc.imsave('face.png', im)          	# uses the Image module (PIL)
plt.imshow(im), plt.axis('off')       	# SciPy 1.2 버전부터 함수 제거됨
plt.show()
# Out:
# C:\Users\bae22\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
import imageio
im = imageio.imread('../images/pepper.jpg')
print(type(im), im.shape, im.dtype)  # <class 'imageio.core.util.Image'> (225, 225, 3) uint8
plt.imshow(im), plt.axis('off')
plt.show()
# Out:
# <class 'imageio.core.util.Array'> (225, 225, 3) uint8

# %% [markdown]
# # 다른 영상 타입과 파일 포멧 처리

# %% [markdown]
# 파일 포멧 및 포멧 변환

# %%
im = Image.open("../images/parrot.png")
print(im.mode)
# RGB
im.save("../images/parrot.jpg")
# Out:
# RGB

# %%
im = Image.open("../images/hill.png")     		# 알파 채널 포함 영상    
print(im.mode)     								# RGBA
im.convert('RGB').save("../images/hill.jpg") 	# 알파 채널 있는 경우 변환 필요
# Out:
# RGBA

# %% [markdown]
# 영상 컬러 모드 및 컬러 변환

# %%
im = imread("../images/parrot.png", as_gray=True)
print(im.shape)                #(362, 486)
# Out:
# (340, 453)

# %%
im = imread("../images/Ishihara.png")
im_g = color.rgb2gray(im)
plt.subplot(121), plt.imshow(im, cmap='gray'), plt.axis('off')
plt.subplot(122), plt.imshow(im_g, cmap='gray'), plt.axis('off')
plt.show()

# %% [markdown]
# ## 컬러 공간 변환

# %%
im = imread("../images/parrot.png")
im_hsv = color.rgb2hsv(im)
plt.figure(figsize=(10,8)), plt.gray()
plt.subplot(221), plt.imshow(im_hsv[...,0])
plt.title('h', size=20), plt.axis('off')
plt.subplot(222), plt.imshow(im_hsv[...,1])
plt.title('s', size=20), plt.axis('off')
plt.subplot(223), plt.imshow(im_hsv[...,2])
plt.title('v', size=20), plt.axis('off')
plt.subplot(224), plt.axis('off')
plt.show()

# %% [markdown]
# ## 영상 저장을 위한 데이터 구조

# %%
im = Image.open('../images/flowers.jpg') # PIL 모둘의 Image 객체로 영상 읽기
im = np.array(im)        				# Image 객체에서 numpy ndarray 생성
imshow(im)               				# skimage 모듈의 imshow 함수 사용해 영상 표시 
plt.axis('off')
show()
# Out:
# ((-0.5, 959.5, 639.5, -0.5), None)

# %%
im = imread('../images/flowers.png')	# skimage로 영상을 numpy ndarray로 읽기
im = Image.fromarray(im)				# ndarray에서 PIL Image 객체 생성 
im.show()       						# PIL Image.show() 함수로 영상 표시
